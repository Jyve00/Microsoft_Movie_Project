# %% [markdown]
# # Data Cleaning bom.movie

# %%
import pandas as pd
import numpy as np

# %%
# !ls
# Out:
# Data                          Top 10 Driectors.png
# Data Cleaning.ipynb           Top 10 Writers.png
# Data Join Visualization.ipynb Top Primary Genre.png
# Director_vs_gross.ipynb       Top Secondary Genre.png
# Profit Primary Genre.png      Top Tertiary Genre.png
# Profit Secondary Genre.png    data.ipynb
# README.md                     main.ipynb
# Stephen.ipynb                 tmdb_movie_clean.ipynb
# Top 10 Actors.png             untitled

# %%
bom = pd.read_csv('Data/bom.movie_gross.csv')

# %%
bom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
bom['foreign_gross'] = bom['foreign_gross'].replace(',','', regex = True)
#getting rid of commas so I can covert string to a float

# %%
bom['foreign_gross']= bom['foreign_gross'].astype(float)
#converting string to float

# %%
top_500_dom = bom.nlargest(500, ['domestic_gross'])

# %%
top_500_dom.isna().sum()
#looking to find if there are many null values in the top 500 movies
#null values aren't relevant in top 500 which means we can get rid of all rows that have nulls
# Out:
# title             0
# studio            0
# domestic_gross    0
# foreign_gross     2
# year              0
# dtype: int64

# %%
bom = bom[bom['domestic_gross'].notna()]

# %%
bom = bom[bom['studio'].notna()]

# %%
bom = bom[bom['foreign_gross'].notna()]

#getting rid of missing values

# %%
bom['worldwide_gross(millions)'] = (bom['domestic_gross'] + bom['foreign_gross'])/(10**6)
bom
# Out:
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross  foreign_gross  year  worldwide_gross(millions)
# 0        415000000.0    652000000.0  2010                  1067.0000
# 1        334200000.0    691300000.0  2010                  1025.5000
# 2        296000000.0    664300000.0  2010                   960.3000
# 3        292600000.0    535700000.0  2010                   828.3000
# 4        238700000.0    513900000.0  2010                   752.6000
# ...              ...            ...   ...                        ...
# 3275          1400.0      1500000.0  2018                     1.5014
# 3286        725000.0       229000.0  2018                     0.9540
# 3309         10000.0       256000.0  2018                     0.2660
# 3342         93200.0         5200.0  2018                     0.0984
# 3353         43200.0        30000.0  2018                     0.0732
#
# [2007 rows x 6 columns]

# %%
bom
# Out:
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross  foreign_gross  year  worldwide_gross(millions)
# 0        415000000.0    652000000.0  2010                  1067.0000
# 1        334200000.0    691300000.0  2010                  1025.5000
# 2        296000000.0    664300000.0  2010                   960.3000
# 3        292600000.0    535700000.0  2010                   828.3000
# 4        238700000.0    513900000.0  2010                   752.6000
# ...              ...            ...   ...                        ...
# 3275          1400.0      1500000.0  2018                     1.5014
# 3286        725000.0       229000.0  2018                     0.9540
# 3309         10000.0       256000.0  2018                     0.2660
# 3342         93200.0         5200.0  2018                     0.0984
# 3353         43200.0        30000.0  2018                     0.0732
#
# [2007 rows x 6 columns]

# %% [markdown]
# ## Data cleaning name.basics

# %%
n_b = pd.read_csv('Data/imdb.name.basics.csv')

# %%
n_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   nconst              606648 non-null  object
#  1   primary_name        606648 non-null  object
#  2   birth_year          82736 non-null   float64
#  3   death_year          6783 non-null    float64
#  4   primary_profession  555308 non-null  object
#  5   known_for_titles    576444 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 27.8+ MB

# %%
n_b = n_b.drop('birth_year', 1)
#deleted birth year because not relevant
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/2995651369.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   n_b = n_b.drop('birth_year', 1)

# %%
n_b = n_b[n_b['death_year'].isna()]
#got rid of any people who are dead

# %%
n_b = n_b.drop('death_year', 1)
#got rid of death year because no longer relevant
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/1327480616.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   n_b = n_b.drop('death_year', 1)

# %%
n_b = n_b[n_b['known_for_titles'].notna()]
# got rid of na values in title id

# %%
n_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 569766 entries, 0 to 606647
# Data columns (total 4 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   nconst              569766 non-null  object
#  1   primary_name        569766 non-null  object
#  2   primary_profession  529154 non-null  object
#  3   known_for_titles    569766 non-null  object
# dtypes: object(4)
# memory usage: 21.7+ MB

# %%
n_b = n_b[n_b['primary_profession'].notna()]
#got rid of na values in primary profession

# %%
n_b
# Out:
#            nconst        primary_name  \
# 0       nm0061671   Mary Ellen Bauder
# 1       nm0061865        Joseph Bauer
# 2       nm0062070          Bruce Baum
# 3       nm0062195        Axel Baumann
# 4       nm0062798         Pete Baxter
# ...           ...                 ...
# 606639  nm9989840  Mariya Shekaturova
# 606640  nm9989854        Layla Louise
# 606644  nm9990690         Joo Yeon So
# 606645  nm9991320      Madeline Smith
# 606647  nm9993380      Pegasus Envoyé
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606639                                             actor
# 606640                                    actress,stunts
# 606644                                           actress
# 606645                                           actress
# 606647                             director,actor,writer
#
#                                known_for_titles
# 0       tt0837562,tt2398241,tt0844471,tt0118553
# 1       tt0896534,tt6791238,tt0287072,tt1682940
# 2       tt1470654,tt0363631,tt0104030,tt0102898
# 3       tt0114371,tt2004304,tt1618448,tt1224387
# 4       tt0452644,tt0452692,tt3458030,tt2178256
# ...                                         ...
# 606639                                tt5953804
# 606640  tt9910102,tt9898328,tt9335490,tt8894778
# 606644                      tt9090932,tt8737130
# 606645                      tt8734436,tt9615610
# 606647                                tt8743182
#
# [529154 rows x 4 columns]

# %% [markdown]
# # Data cleaning title.akas

# %%
t_a = pd.read_csv('Data/imdb.title.akas.csv')

# %%
t_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   title_id           331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   language           41715 non-null   object
#  5   types              168447 non-null  object
#  6   attributes         14925 non-null   object
#  7   is_original_title  331678 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.2+ MB

# %%
t_a = t_a.drop('language', 1)

#dropped language because too many na's
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/3790387345.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   t_a = t_a.drop('language', 1)

# %%
t_a = t_a.drop('types', 1)
#dropped types because too many na's, not relevant
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/2448917448.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   t_a = t_a.drop('types', 1)

# %%
t_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   title_id           331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   attributes         14925 non-null   object
#  5   is_original_title  331678 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 15.2+ MB

# %%
t_a = t_a.drop('attributes', 1)
#dropped attributes because too many na's
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/557549458.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   t_a = t_a.drop('attributes', 1)

# %%
# t_a.set_index('title_id', inplace = True)
# setting the title id as index

# %%
t_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   title_id           331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   is_original_title  331678 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 12.7+ MB

# %%
is_original_title = t_a['is_original_title'] == 1

# %%
is_original_title = t_a[is_original_title]

# %%
t_a = is_original_title
#I only want original titles to get rid of repeats

# %%
t_a = t_a.drop('region', 1)
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/546605675.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   t_a = t_a.drop('region', 1)

# %%
t_a = t_a.drop('ordering', 1)
#region and ordering are not relevant
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/841517945.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   t_a = t_a.drop('ordering', 1)

# %%
# Create new column tconst listing title id
t_a['tconst'] = t_a['title_id']

# %%
# Drop column title id since it is duplicate
t_a = t_a.drop('title_id', 1)
t_a
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/3107290540.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   t_a = t_a.drop('title_id', 1)
#                                                     title  is_original_title  \
# 38                                         Jurassic World                1.0
# 80                                            John Carter                1.0
# 83      Versailles Rediscovered - The Sun King's Vanis...                1.0
# 86                          Miguelito - Canto a Borinquen                1.0
# 90                                      Thing I Don't Get                1.0
# ...                                                   ...                ...
# 331690                         Anderswo. Allein in Afrika                1.0
# 331692                           Monkey King: The Volcano                1.0
# 331696                                          Big Shark                1.0
# 331698                                 Sayonara kuchibiru                1.0
# 331700                                        La atención                1.0
#
#             tconst
# 38       tt0369610
# 80       tt0401729
# 83      tt10010134
# 86      tt10027708
# 90      tt10050722
# ...            ...
# 331690   tt9723084
# 331692   tt9726638
# 331696   tt9755806
# 331698   tt9827784
# 331700   tt9880178
#
# [44700 rows x 3 columns]

# %% [markdown]
# #data cleaning title basics

# %%
# !ls
# Out:
# Data                          Top 10 Driectors.png
# Data Cleaning.ipynb           Top 10 Writers.png
# Data Join Visualization.ipynb Top Primary Genre.png
# Director_vs_gross.ipynb       Top Secondary Genre.png
# Profit Primary Genre.png      Top Tertiary Genre.png
# Profit Secondary Genre.png    data.ipynb
# README.md                     main.ipynb
# Stephen.ipynb                 tmdb_movie_clean.ipynb
# Top 10 Actors.png             untitled

# %% [markdown]
# # Data cleaning title basics

# %%
t_b = pd.read_csv('Data/imdb.title.basics.csv')

# %%
t_b
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                   NaN
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
t_b = t_b.drop('runtime_minutes', 1)
#don think runtime is relevant data
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/3839429948.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   t_b = t_b.drop('runtime_minutes', 1)

# %%
t_b = t_b[t_b['genres'].notna()]
#getting rid of na values in genres

# %%
t_b = t_b.drop('original_title', 1)
#getting rid of og title because not necessary
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/148550685.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   t_b = t_b.drop('original_title', 1)

# %% [markdown]
# # data cleaning title crew

# %%
t_c = pd.read_csv('Data/imdb.title.crew.csv.gz')

# %%
t_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  140417 non-null  object
#  2   writers    110261 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
t_c = t_c[t_c['directors'].notna()]

# %%
t_c = t_c[t_c['writers'].notna()]
#got rid of na values

# %%
t_c.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# 6  tt0996958                      nm2286991  nm2286991,nm2651190

# %% [markdown]
# # data cleaning title principals

# %%
t_p = pd.read_csv('Data/imdb.title.principals.csv')

# %%
t_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   tconst      1028186 non-null  object
#  1   ordering    1028186 non-null  int64
#  2   nconst      1028186 non-null  object
#  3   category    1028186 non-null  object
#  4   job         177684 non-null   object
#  5   characters  393360 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB

# %%
t_p = t_p.drop('characters',1)
# dropped characters not relevant
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/2881274645.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   t_p = t_p.drop('characters',1)

# %%
t_p = t_p.drop('ordering',1)
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/3368346571.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   t_p = t_p.drop('ordering',1)

# %%
t_p = t_p.drop('job', 1)
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/686105864.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   t_p = t_p.drop('job', 1)

# %%
t_p.rename({'category':'job'}, axis = 1, inplace = True)
#changed category to job because more accurate

# %%
t_p.head()
# Out:
#       tconst     nconst       job
# 0  tt0111414  nm0246005     actor
# 1  tt0111414  nm0398271  director
# 2  tt0111414  nm3739909  producer
# 3  tt0323808  nm0059247    editor
# 4  tt0323808  nm3579312   actress

# %% [markdown]
# # Data cleaning title rating

# %%
t_r = pd.read_csv('Data/imdb.title.ratings.csv.gz')

# %%
t_r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
t_r.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %% [markdown]
# # Data Merge & Visualization

# %%
# Import python tools for visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# List the info of the df that are being used
print('bom')
bom.info()
print()
print('n_b')
n_b.info()
print()
print('t_a')
t_a.info()
print()
print('t_b')
t_b.info()
print()
print('t_p')
t_p.info()
# Out:
# bom
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2007 entries, 0 to 3353
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   title                      2007 non-null   object
#  1   studio                     2007 non-null   object
#  2   domestic_gross             2007 non-null   float64
#  3   foreign_gross              2007 non-null   float64
#  4   year                       2007 non-null   int64
#  5   worldwide_gross(millions)  2007 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 109.8+ KB
#
# n_b
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 529154 entries, 0 to 606647
# Data columns (total 4 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   nconst              529154 non-null  object
#  1   primary_name        529154 non-null  object
#  2   primary_profession  529154 non-null  object
#  3   known_for_titles    529154 non-null  object
# dtypes: object(4)
# memory usage: 20.2+ MB
#
# t_a
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44700 entries, 38 to 331700
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              44700 non-null  object
#  1   is_original_title  44700 non-null  float64
#  2   tconst             44700 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 1.4+ MB
#
# t_b
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140736 entries, 0 to 146143
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         140736 non-null  object
#  1   primary_title  140736 non-null  object
#  2   start_year     140736 non-null  int64
#  3   genres         140736 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 5.4+ MB
#
# t_p
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 3 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   tconst  1028186 non-null  object
#  1   nconst  1028186 non-null  object
#  2   job     1028186 non-null  object
# dtypes: object(3)
# memory usage: 23.5+ MB

# %%
# Create a bar chart for average world wide profit for each genre
# Join the dataframe bom, t_a, and t_b into new dataframe pg (profit-gross)
pg1 = bom.merge(t_a, on = 'title', how = 'inner')
# check
#pg1
pg2 = pg1.merge(t_b, on ='tconst', how = 'inner')
pg2
# Out:
#                                         title      studio  domestic_gross  \
# 0                                 Toy Story 3          BV     415000000.0
# 1                                   Inception          WB     292600000.0
# 2                         Shrek Forever After        P/DW     238700000.0
# 3                  The Twilight Saga: Eclipse        Sum.     300500000.0
# 4                                  Iron Man 2        Par.     312400000.0
# ...                                       ...         ...             ...
# 1420               Bilal: A New Breed of Hero          VE        491000.0
# 1421                          I Still See You         LGF          1400.0
# 1422                    The Catcher Was a Spy         IFC        725000.0
# 1423                               Time Freak  Grindstone         10000.0
# 1424  Antonio Lopez 1970: Sex Fashion & Disco          FM         43200.0
#
#       foreign_gross  year  worldwide_gross(millions)  is_original_title  \
# 0       652000000.0  2010                  1067.0000                1.0
# 1       535700000.0  2010                   828.3000                1.0
# 2       513900000.0  2010                   752.6000                1.0
# 3       398000000.0  2010                   698.5000                1.0
# 4       311500000.0  2010                   623.9000                1.0
# ...             ...   ...                        ...                ...
# 1420      1700000.0  2018                     2.1910                1.0
# 1421      1500000.0  2018                     1.5014                1.0
# 1422       229000.0  2018                     0.9540                1.0
# 1423       256000.0  2018                     0.2660                1.0
# 1424        30000.0  2018                     0.0732                1.0
#
#          tconst                            primary_title  start_year  \
# 0     tt0435761                              Toy Story 3        2010
# 1     tt1375666                                Inception        2010
# 2     tt0892791                      Shrek Forever After        2010
# 3     tt1325004               The Twilight Saga: Eclipse        2010
# 4     tt1228705                               Iron Man 2        2010
# ...         ...                                      ...         ...
# 1420  tt3576728               Bilal: A New Breed of Hero        2015
# 1421  tt2160105                          I Still See You        2018
# 1422  tt4602066                    The Catcher Was a Spy        2018
# 1423  tt6769280                               Time Freak        2018
# 1424  tt5792490  Antonio Lopez 1970: Sex Fashion & Disco        2017
#
#                           genres
# 0     Adventure,Animation,Comedy
# 1        Action,Adventure,Sci-Fi
# 2     Adventure,Animation,Comedy
# 3        Adventure,Drama,Fantasy
# 4        Action,Adventure,Sci-Fi
# ...                          ...
# 1420  Action,Adventure,Animation
# 1421            Fantasy,Thriller
# 1422         Biography,Drama,War
# 1423        Comedy,Drama,Romance
# 1424       Biography,Documentary
#
# [1425 rows x 11 columns]

# %% [markdown]
# Genre column contains multiple values. Therefore we need to split it.

# %%
# split genre with multiple values into 3 separate columns
split_genre = pg2['genres'].str.split(",")
genre = split_genre.to_list()
genre_cols = ['genre 1', "genre 2", "genre 3"]
genre_df = pd.DataFrame(genre, columns=genre_cols)
genre_df.head()
# Out:
#      genre 1    genre 2  genre 3
# 0  Adventure  Animation   Comedy
# 1     Action  Adventure   Sci-Fi
# 2  Adventure  Animation   Comedy
# 3  Adventure      Drama  Fantasy
# 4     Action  Adventure   Sci-Fi

# %%
# Create a split genre columns in pg2
pg2['genre 1'] = genre_df['genre 1']
pg2['genre 2'] = genre_df['genre 2']
pg2['genre 3'] = genre_df['genre 3']
pg2
# Out:
#                                         title      studio  domestic_gross  \
# 0                                 Toy Story 3          BV     415000000.0
# 1                                   Inception          WB     292600000.0
# 2                         Shrek Forever After        P/DW     238700000.0
# 3                  The Twilight Saga: Eclipse        Sum.     300500000.0
# 4                                  Iron Man 2        Par.     312400000.0
# ...                                       ...         ...             ...
# 1420               Bilal: A New Breed of Hero          VE        491000.0
# 1421                          I Still See You         LGF          1400.0
# 1422                    The Catcher Was a Spy         IFC        725000.0
# 1423                               Time Freak  Grindstone         10000.0
# 1424  Antonio Lopez 1970: Sex Fashion & Disco          FM         43200.0
#
#       foreign_gross  year  worldwide_gross(millions)  is_original_title  \
# 0       652000000.0  2010                  1067.0000                1.0
# 1       535700000.0  2010                   828.3000                1.0
# 2       513900000.0  2010                   752.6000                1.0
# 3       398000000.0  2010                   698.5000                1.0
# 4       311500000.0  2010                   623.9000                1.0
# ...             ...   ...                        ...                ...
# 1420      1700000.0  2018                     2.1910                1.0
# 1421      1500000.0  2018                     1.5014                1.0
# 1422       229000.0  2018                     0.9540                1.0
# 1423       256000.0  2018                     0.2660                1.0
# 1424        30000.0  2018                     0.0732                1.0
#
#          tconst                            primary_title  start_year  \
# 0     tt0435761                              Toy Story 3        2010
# 1     tt1375666                                Inception        2010
# 2     tt0892791                      Shrek Forever After        2010
# 3     tt1325004               The Twilight Saga: Eclipse        2010
# 4     tt1228705                               Iron Man 2        2010
# ...         ...                                      ...         ...
# 1420  tt3576728               Bilal: A New Breed of Hero        2015
# 1421  tt2160105                          I Still See You        2018
# 1422  tt4602066                    The Catcher Was a Spy        2018
# 1423  tt6769280                               Time Freak        2018
# 1424  tt5792490  Antonio Lopez 1970: Sex Fashion & Disco        2017
#
#                           genres    genre 1      genre 2    genre 3
# 0     Adventure,Animation,Comedy  Adventure    Animation     Comedy
# 1        Action,Adventure,Sci-Fi     Action    Adventure     Sci-Fi
# 2     Adventure,Animation,Comedy  Adventure    Animation     Comedy
# 3        Adventure,Drama,Fantasy  Adventure        Drama    Fantasy
# 4        Action,Adventure,Sci-Fi     Action    Adventure     Sci-Fi
# ...                          ...        ...          ...        ...
# 1420  Action,Adventure,Animation     Action    Adventure  Animation
# 1421            Fantasy,Thriller    Fantasy     Thriller       None
# 1422         Biography,Drama,War  Biography        Drama        War
# 1423        Comedy,Drama,Romance     Comedy        Drama    Romance
# 1424       Biography,Documentary  Biography  Documentary       None
#
# [1425 rows x 14 columns]

# %%
# Analyze the Genre Frequency for each genre column
genre_df.describe()
# Out:
#        genre 1 genre 2   genre 3
# count     1425    1273       930
# unique      15      20        19
# top     Action   Drama  Thriller
# freq       389     355       171

# %%
# Primary Genre Analysis
# Create a figure and axis
fig, ax = plt.subplots(figsize=(15,6))
# Count the frequency in of each genre in genre 1
data = genre_df['genre 1'].value_counts().head(10)
# Get x and y data
x = data.index
y = data.values 
# Create bar chart
ax.bar(x, y) 
# Set title and labels
ax.set_title('Top Primary Genres')
ax.set_xlabel('Genre')
ax.set_ylabel('Frequency')
# Save figure
plt.savefig('Top Primary Genre.png')

# %%
# Secondary Genre Analysis
# Create a figure and axis
fig, ax = plt.subplots(figsize=(15,6))
# Count the frequency in of each genre in genre 2
data = genre_df['genre 2'].value_counts().head(10)
# Set x and y data
x = data.index
y = data.values 
# Create bar chart
ax.bar(x, y) 
# Set title and labels
ax.set_title('Top Secondary Genres')
ax.set_xlabel('Genre')
ax.set_ylabel('Frequency')
# Save figure
plt.savefig('Top Secondary Genre.png')

# %%
# Tertiary Genre Analysis
# Create a figure and axis
fig, ax = plt.subplots(figsize=(15,6))
# Count the frequency in of each genre in genre 3
data = genre_df['genre 3'].value_counts().head(10)
# Get x and y data
x = data.index
y = data.values 
# Create bar chart
ax.bar(x, y) 
# Set title and labels
ax.set_title('Top Tertiary Genres')
ax.set_xlabel('Genre')
ax.set_ylabel('Frequency')
# Save figure
plt.savefig('Top Tertiary Genre.png')

# %%
pg2['worldwide_gross'] = pg2['worldwide_gross(millions)']
pg2 = pg2.drop('worldwide_gross(millions)', 1)
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/1968031342.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   pg2 = pg2.drop('worldwide_gross(millions)', 1)

# %%
# Find the average worldwide profit by genre
# Group by the primary genre (genre 1 ) with average worldwide gross profit
profit_genre = pg2.groupby(['genre 1']).worldwide_gross.mean()
profit_genre
# Out:
# genre 1
# Action         241.334093
# Adventure      277.733003
# Animation      197.746808
# Biography       71.629573
# Comedy          70.539559
# Crime           61.043074
# Documentary     31.897348
# Drama           60.249536
# Family         857.600000
# Fantasy         27.694100
# Horror          99.202727
# Music            8.000000
# Mystery        108.205000
# Romance         35.394775
# Thriller        72.305240
# Name: worldwide_gross, dtype: float64

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(15,6))
# Set x and y data
x = profit_genre.index
y = profit_genre.values 
# Create bar chart
ax.bar(x, y) 
# Set title and labels
ax.set_title('Average Worldwide Profit across Primary Genre')
ax.set_xlabel('Genre')
ax.set_ylabel('Worldwide Profit (M)') # Find an ROI or budget  Rn is revenue 
# Save figure
plt.savefig('Profit Primary Genre.png')

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(20,6))
# Group by the secondary genre (genre 2 ) with average worldwide gross profit
profit_genre2 = pg2.groupby(['genre 2']).worldwide_gross.mean()
# Set x and y data
x = profit_genre2.index
y = profit_genre2.values 
# Create bar chart
ax.bar(x, y) 
# Set title and labels
ax.set_title('Average Worldwide Profit across Secondary Genre')
ax.set_xlabel('Genre')
ax.set_ylabel('Worldwide Profit (M)')
# Save figure
plt.savefig('Profit Secondary Genre.png')

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(20,6))
# Group by the tertiary genre (genre 3 ) with average worldwide gross profit
profit_genre3 = pg2.groupby(['genre 3']).worldwide_gross.mean()
# Set x and y data
x = profit_genre3.index
y = profit_genre3.values 
# Create bar chart
ax.bar(x, y) 
# Set title and labels
ax.set_title('Average Worldwide Profit across Tertiary Genre')
ax.set_xlabel('Genre')
ax.set_ylabel('Worldwide Profit (M)')
# Save figure
#plt.savefig('Profit Tertiary Genre.png')
# Out:
# Text(0, 0.5, 'Worldwide Profit (M)')

# %%
#genre_year = {}
#years = pg2['year'].unique().tolist()
#for year in years:

# %%
# Merge title principle with the profit genre dataframe
pg3 = pg2.merge(t_p, on = 'tconst', how = 'inner')

# %%
pg3
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                                  Toy Story 3     BV     415000000.0
# 2                                  Toy Story 3     BV     415000000.0
# 3                                  Toy Story 3     BV     415000000.0
# 4                                  Toy Story 3     BV     415000000.0
# ...                                        ...    ...             ...
# 14097  Antonio Lopez 1970: Sex Fashion & Disco     FM         43200.0
# 14098  Antonio Lopez 1970: Sex Fashion & Disco     FM         43200.0
# 14099  Antonio Lopez 1970: Sex Fashion & Disco     FM         43200.0
# 14100  Antonio Lopez 1970: Sex Fashion & Disco     FM         43200.0
# 14101  Antonio Lopez 1970: Sex Fashion & Disco     FM         43200.0
#
#        foreign_gross  year  is_original_title     tconst  \
# 0        652000000.0  2010                1.0  tt0435761
# 1        652000000.0  2010                1.0  tt0435761
# 2        652000000.0  2010                1.0  tt0435761
# 3        652000000.0  2010                1.0  tt0435761
# 4        652000000.0  2010                1.0  tt0435761
# ...              ...   ...                ...        ...
# 14097        30000.0  2018                1.0  tt5792490
# 14098        30000.0  2018                1.0  tt5792490
# 14099        30000.0  2018                1.0  tt5792490
# 14100        30000.0  2018                1.0  tt5792490
# 14101        30000.0  2018                1.0  tt5792490
#
#                                  primary_title  start_year  \
# 0                                  Toy Story 3        2010
# 1                                  Toy Story 3        2010
# 2                                  Toy Story 3        2010
# 3                                  Toy Story 3        2010
# 4                                  Toy Story 3        2010
# ...                                        ...         ...
# 14097  Antonio Lopez 1970: Sex Fashion & Disco        2017
# 14098  Antonio Lopez 1970: Sex Fashion & Disco        2017
# 14099  Antonio Lopez 1970: Sex Fashion & Disco        2017
# 14100  Antonio Lopez 1970: Sex Fashion & Disco        2017
# 14101  Antonio Lopez 1970: Sex Fashion & Disco        2017
#
#                            genres    genre 1      genre 2 genre 3  \
# 0      Adventure,Animation,Comedy  Adventure    Animation  Comedy
# 1      Adventure,Animation,Comedy  Adventure    Animation  Comedy
# 2      Adventure,Animation,Comedy  Adventure    Animation  Comedy
# 3      Adventure,Animation,Comedy  Adventure    Animation  Comedy
# 4      Adventure,Animation,Comedy  Adventure    Animation  Comedy
# ...                           ...        ...          ...     ...
# 14097       Biography,Documentary  Biography  Documentary    None
# 14098       Biography,Documentary  Biography  Documentary    None
# 14099       Biography,Documentary  Biography  Documentary    None
# 14100       Biography,Documentary  Biography  Documentary    None
# 14101       Biography,Documentary  Biography  Documentary    None
#
#        worldwide_gross     nconst              job
# 0            1067.0000  nm0005271         composer
# 1            1067.0000  nm0000158            actor
# 2            1067.0000  nm0000741            actor
# 3            1067.0000  nm0000349          actress
# 4            1067.0000  nm0000885            actor
# ...                ...        ...              ...
# 14097           0.0732  nm0159510  archive_footage
# 14098           0.0732  nm2615851         director
# 14099           0.0732  nm4333147         producer
# 14100           0.0732  nm1756961  cinematographer
# 14101           0.0732  nm2166584           editor
#
# [14102 rows x 16 columns]

# %%
# Merge name basic with the profit genre dataframe
pg4 = pg3.merge(n_b, on = 'nconst', how = 'inner')

# %%
pg4
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                          Monsters University     BV     268500000.0
# 2                                  Toy Story 3     BV     415000000.0
# 3                                 Larry Crowne   Uni.      35600000.0
# 4            Extremely Loud & Incredibly Close     WB      31800000.0
# ...                                        ...    ...             ...
# 13688  Antonio Lopez 1970: Sex Fashion & Disco     FM         43200.0
# 13689  Antonio Lopez 1970: Sex Fashion & Disco     FM         43200.0
# 13690  Antonio Lopez 1970: Sex Fashion & Disco     FM         43200.0
# 13691  Antonio Lopez 1970: Sex Fashion & Disco     FM         43200.0
# 13692  Antonio Lopez 1970: Sex Fashion & Disco     FM         43200.0
#
#        foreign_gross  year  is_original_title     tconst  \
# 0        652000000.0  2010                1.0  tt0435761
# 1        475700000.0  2013                1.0  tt1453405
# 2        652000000.0  2010                1.0  tt0435761
# 3         36400000.0  2011                1.0  tt1583420
# 4         23400000.0  2011                1.0  tt0477302
# ...              ...   ...                ...        ...
# 13688        30000.0  2018                1.0  tt5792490
# 13689        30000.0  2018                1.0  tt5792490
# 13690        30000.0  2018                1.0  tt5792490
# 13691        30000.0  2018                1.0  tt5792490
# 13692        30000.0  2018                1.0  tt5792490
#
#                                  primary_title  start_year  \
# 0                                  Toy Story 3        2010
# 1                          Monsters University        2013
# 2                                  Toy Story 3        2010
# 3                                 Larry Crowne        2011
# 4            Extremely Loud & Incredibly Close        2011
# ...                                        ...         ...
# 13688  Antonio Lopez 1970: Sex Fashion & Disco        2017
# 13689  Antonio Lopez 1970: Sex Fashion & Disco        2017
# 13690  Antonio Lopez 1970: Sex Fashion & Disco        2017
# 13691  Antonio Lopez 1970: Sex Fashion & Disco        2017
# 13692  Antonio Lopez 1970: Sex Fashion & Disco        2017
#
#                            genres    genre 1      genre 2  genre 3  \
# 0      Adventure,Animation,Comedy  Adventure    Animation   Comedy
# 1      Adventure,Animation,Comedy  Adventure    Animation   Comedy
# 2      Adventure,Animation,Comedy  Adventure    Animation   Comedy
# 3            Comedy,Drama,Romance     Comedy        Drama  Romance
# 4         Adventure,Drama,Mystery  Adventure        Drama  Mystery
# ...                           ...        ...          ...      ...
# 13688       Biography,Documentary  Biography  Documentary     None
# 13689       Biography,Documentary  Biography  Documentary     None
# 13690       Biography,Documentary  Biography  Documentary     None
# 13691       Biography,Documentary  Biography  Documentary     None
# 13692       Biography,Documentary  Biography  Documentary     None
#
#        worldwide_gross     nconst              job      primary_name  \
# 0            1067.0000  nm0005271         composer      Randy Newman
# 1             744.2000  nm0005271         composer      Randy Newman
# 2            1067.0000  nm0000158            actor         Tom Hanks
# 3              72.0000  nm0000158            actor         Tom Hanks
# 4              55.2000  nm0000158            actor         Tom Hanks
# ...                ...        ...              ...               ...
# 13688           0.0732  nm0118371             self  Joan Juliet Buck
# 13689           0.0732  nm0159485             self      Michael Chow
# 13690           0.0732  nm2615851         director       James Crump
# 13691           0.0732  nm1756961  cinematographer    Robert O'Haire
# 13692           0.0732  nm2166584           editor     Nick Tamburri
#
#                                       primary_profession  \
# 0                   soundtrack,music_department,composer
# 1                   soundtrack,music_department,composer
# 2                              producer,actor,soundtrack
# 3                              producer,actor,soundtrack
# 4                              producer,actor,soundtrack
# ...                                                  ...
# 13688                                            actress
# 13689                                              actor
# 13690                           director,writer,producer
# 13691  sound_department,cinematographer,camera_depart...
# 13692                editor,miscellaneous,visual_effects
#
#                               known_for_titles
# 0      tt0435761,tt0114709,tt0780521,tt0212338
# 1      tt0435761,tt0114709,tt0780521,tt0212338
# 2      tt0094737,tt0162222,tt0120815,tt0109830
# 3      tt0094737,tt0162222,tt0120815,tt0109830
# 4      tt0094737,tt0162222,tt0120815,tt0109830
# ...                                        ...
# 13688                      tt4016454,tt1135503
# 13689  tt0120812,tt0062512,tt1078588,tt0122151
# 13690            tt5792490,tt1003113,tt4096620
# 13691  tt0780625,tt4123650,tt1961535,tt4683968
# 13692  tt1470730,tt2529256,tt1196682,tt3380298
#
# [13693 rows x 19 columns]

# %%
# Rename all merged dataframe to df_merged
df_merged = pg4

# %% [raw]
# From merged dataframe remove unnecessary and duplicated columns

# %%
df_merged.info()
df_merged.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13693 entries, 0 to 13692
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               13693 non-null  object
#  1   studio              13693 non-null  object
#  2   domestic_gross      13693 non-null  float64
#  3   foreign_gross       13693 non-null  float64
#  4   year                13693 non-null  int64
#  5   is_original_title   13693 non-null  float64
#  6   tconst              13693 non-null  object
#  7   primary_title       13693 non-null  object
#  8   start_year          13693 non-null  int64
#  9   genres              13693 non-null  object
#  10  genre 1             13693 non-null  object
#  11  genre 2             12329 non-null  object
#  12  genre 3             9017 non-null   object
#  13  worldwide_gross     13693 non-null  float64
#  14  nconst              13693 non-null  object
#  15  job                 13693 non-null  object
#  16  primary_name        13693 non-null  object
#  17  primary_profession  13693 non-null  object
#  18  known_for_titles    13693 non-null  object
# dtypes: float64(4), int64(2), object(13)
# memory usage: 2.1+ MB
#                                title studio  domestic_gross  foreign_gross  \
# 0                        Toy Story 3     BV     415000000.0    652000000.0
# 1                Monsters University     BV     268500000.0    475700000.0
# 2                        Toy Story 3     BV     415000000.0    652000000.0
# 3                       Larry Crowne   Uni.      35600000.0     36400000.0
# 4  Extremely Loud & Incredibly Close     WB      31800000.0     23400000.0
#
#    year  is_original_title     tconst                      primary_title  \
# 0  2010                1.0  tt0435761                        Toy Story 3
# 1  2013                1.0  tt1453405                Monsters University
# 2  2010                1.0  tt0435761                        Toy Story 3
# 3  2011                1.0  tt1583420                       Larry Crowne
# 4  2011                1.0  tt0477302  Extremely Loud & Incredibly Close
#
#    start_year                      genres    genre 1    genre 2  genre 3  \
# 0        2010  Adventure,Animation,Comedy  Adventure  Animation   Comedy
# 1        2013  Adventure,Animation,Comedy  Adventure  Animation   Comedy
# 2        2010  Adventure,Animation,Comedy  Adventure  Animation   Comedy
# 3        2011        Comedy,Drama,Romance     Comedy      Drama  Romance
# 4        2011     Adventure,Drama,Mystery  Adventure      Drama  Mystery
#
#    worldwide_gross     nconst       job  primary_name  \
# 0           1067.0  nm0005271  composer  Randy Newman
# 1            744.2  nm0005271  composer  Randy Newman
# 2           1067.0  nm0000158     actor     Tom Hanks
# 3             72.0  nm0000158     actor     Tom Hanks
# 4             55.2  nm0000158     actor     Tom Hanks
#
#                      primary_profession  \
# 0  soundtrack,music_department,composer
# 1  soundtrack,music_department,composer
# 2             producer,actor,soundtrack
# 3             producer,actor,soundtrack
# 4             producer,actor,soundtrack
#
#                           known_for_titles
# 0  tt0435761,tt0114709,tt0780521,tt0212338
# 1  tt0435761,tt0114709,tt0780521,tt0212338
# 2  tt0094737,tt0162222,tt0120815,tt0109830
# 3  tt0094737,tt0162222,tt0120815,tt0109830
# 4  tt0094737,tt0162222,tt0120815,tt0109830

# %%
df_merged = df_merged.drop(columns=['domestic_gross','foreign_gross', 'is_original_title', 'primary_title' 
                                    ,'genres', 'start_year', 'nconst', 'primary_profession', 'known_for_titles', 'tconst'], axis = 1)

# %%
df_merged.head()
# Out:
#                                title studio  year    genre 1    genre 2  \
# 0                        Toy Story 3     BV  2010  Adventure  Animation
# 1                Monsters University     BV  2013  Adventure  Animation
# 2                        Toy Story 3     BV  2010  Adventure  Animation
# 3                       Larry Crowne   Uni.  2011     Comedy      Drama
# 4  Extremely Loud & Incredibly Close     WB  2011  Adventure      Drama
#
#    genre 3  worldwide_gross       job  primary_name
# 0   Comedy           1067.0  composer  Randy Newman
# 1   Comedy            744.2  composer  Randy Newman
# 2   Comedy           1067.0     actor     Tom Hanks
# 3  Romance             72.0     actor     Tom Hanks
# 4  Mystery             55.2     actor     Tom Hanks

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13693 entries, 0 to 13692
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            13693 non-null  object
#  1   studio           13693 non-null  object
#  2   year             13693 non-null  int64
#  3   genre 1          13693 non-null  object
#  4   genre 2          12329 non-null  object
#  5   genre 3          9017 non-null   object
#  6   worldwide_gross  13693 non-null  float64
#  7   job              13693 non-null  object
#  8   primary_name     13693 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 1.0+ MB

# %%
df_merged['job'].value_counts()
# Out:
# actor                  3420
# producer               2710
# writer                 2421
# actress                2055
# director               1501
# composer                754
# cinematographer         449
# editor                  241
# self                     72
# production_designer      65
# archive_footage           5
# Name: job, dtype: int64

# %% [raw]
# Value self means the 'actor' came out as him or her in the film based on real story. Therefore, convert 'self' to 'actor'.
# Also, the actor and actress has separate values. We are converting those into one value 'actor'.

# %%
df_merged.iloc[df_merged['job'] == 'self', df_merged.columns.get_loc('job')] = 'actor'
df_merged.iloc[df_merged['job'] == 'actress',  df_merged.columns.get_loc('job')] = 'actor'

# %%
# Check the result
df_merged['job'].value_counts()
# Out:
# actor                  5547
# producer               2710
# writer                 2421
# director               1501
# composer                754
# cinematographer         449
# editor                  241
# production_designer      65
# archive_footage           5
# Name: job, dtype: int64

# %%
df_merged
# Out:
#                                          title studio  year    genre 1  \
# 0                                  Toy Story 3     BV  2010  Adventure
# 1                          Monsters University     BV  2013  Adventure
# 2                                  Toy Story 3     BV  2010  Adventure
# 3                                 Larry Crowne   Uni.  2011     Comedy
# 4            Extremely Loud & Incredibly Close     WB  2011  Adventure
# ...                                        ...    ...   ...        ...
# 13688  Antonio Lopez 1970: Sex Fashion & Disco     FM  2018  Biography
# 13689  Antonio Lopez 1970: Sex Fashion & Disco     FM  2018  Biography
# 13690  Antonio Lopez 1970: Sex Fashion & Disco     FM  2018  Biography
# 13691  Antonio Lopez 1970: Sex Fashion & Disco     FM  2018  Biography
# 13692  Antonio Lopez 1970: Sex Fashion & Disco     FM  2018  Biography
#
#            genre 2  genre 3  worldwide_gross              job  \
# 0        Animation   Comedy        1067.0000         composer
# 1        Animation   Comedy         744.2000         composer
# 2        Animation   Comedy        1067.0000            actor
# 3            Drama  Romance          72.0000            actor
# 4            Drama  Mystery          55.2000            actor
# ...            ...      ...              ...              ...
# 13688  Documentary     None           0.0732            actor
# 13689  Documentary     None           0.0732            actor
# 13690  Documentary     None           0.0732         director
# 13691  Documentary     None           0.0732  cinematographer
# 13692  Documentary     None           0.0732           editor
#
#            primary_name
# 0          Randy Newman
# 1          Randy Newman
# 2             Tom Hanks
# 3             Tom Hanks
# 4             Tom Hanks
# ...                 ...
# 13688  Joan Juliet Buck
# 13689      Michael Chow
# 13690       James Crump
# 13691    Robert O'Haire
# 13692     Nick Tamburri
#
# [13693 rows x 9 columns]

# %%
# Create the dataframe that only contains job = director
df_director = df_merged.loc[df_merged['job'] == 'director']
df_director
# Out:
#                                          title      studio  year    genre 1  \
# 20                                 Toy Story 3          BV  2010  Adventure
# 21                                        Coco          BV  2017  Adventure
# 23                                      Cars 2          BV  2011  Adventure
# 26                                 John Carter          BV  2012     Action
# 27                                Finding Dory          BV  2016  Adventure
# ...                                        ...         ...   ...        ...
# 13641                            Blindspotting        LG/S  2018     Comedy
# 13670               Bilal: A New Breed of Hero          VE  2018     Action
# 13671               Bilal: A New Breed of Hero          VE  2018     Action
# 13684                               Time Freak  Grindstone  2018     Comedy
# 13690  Antonio Lopez 1970: Sex Fashion & Disco          FM  2018  Biography
#
#            genre 2    genre 3  worldwide_gross       job          primary_name
# 20       Animation     Comedy        1067.0000  director           Lee Unkrich
# 21       Animation     Comedy         807.1000  director           Lee Unkrich
# 23       Animation     Comedy         562.2000  director         John Lasseter
# 26       Adventure     Sci-Fi         284.2000  director        Andrew Stanton
# 27       Animation     Comedy        1028.6000  director        Andrew Stanton
# ...            ...        ...              ...       ...                   ...
# 13641        Crime      Drama           4.8300  director  Carlos López Estrada
# 13670    Adventure  Animation           2.1910  director      Khurram H. Alavi
# 13671    Adventure  Animation           2.1910  director           Ayman Jamal
# 13684        Drama    Romance           0.2660  director         Andrew Bowler
# 13690  Documentary       None           0.0732  director           James Crump
#
# [1501 rows x 9 columns]

# %%
profit_director = df_director.groupby(['primary_name']).worldwide_gross.mean()
profit_director = profit_director.sort_values(ascending = False)
profit_director = profit_director.nlargest(n=10)

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(15,6))
# Set x and y data
x = profit_director.index
y = profit_director.values 
# Create bar chart
ax.bar(x, y) 
# Set title and labels
ax.set_title('Top 10 Director')
ax.set_xlabel('Driector')
ax.set_ylabel('Worldwide Profit (M)')
# Save figure
plt.savefig('Top 10 Driectors.png')

# %%
# Create the dataframe that only contains job = actor
df_actor = df_merged.loc[df_merged['job'] == 'actor']
profit_actor = df_actor.groupby(['primary_name']).worldwide_gross.mean()
profit_actor = profit_actor.sort_values(ascending = False)
profit_actor = profit_actor.nlargest(n=10)
# Create a figure and axis
fig, ax = plt.subplots(figsize=(15,6))
# Set x and y data
x = profit_actor.index
y = profit_actor.values 
# Create bar chart
ax.bar(x, y) 
# Set title and labels
ax.set_title('Top 10 Actor')
ax.set_xlabel('Actor')
ax.set_ylabel('Worldwide Profit (M)')
# Save figure
plt.savefig('Top 10 Actors.png')

# %%
# Create the dataframe that only contains job = writer
df_writer = df_merged.loc[df_merged['job'] == 'writer']
# Create the data by grouping name of the writer by the average worldwide gross profit
profit_writer = df_writer.groupby(['primary_name']).worldwide_gross.mean()

profit_writer = profit_writer.sort_values(ascending = False)
profit_writer = profit_writer.nlargest(n=10)
# Create a figure and axis
fig, ax = plt.subplots(figsize=(15,6))
# Set x and y data
x = profit_writer.index
y = profit_writer.values 
# Create bar chart
ax.bar(x, y) 
# Set title and labels
ax.set_title('Top 10 Writer')
ax.set_xlabel('Writer')
ax.set_ylabel('Worldwide Profit (M)')
# Save figure
plt.savefig('Top 10 Writers.png')

# %%
t_m = pd.read_csv('Data/tmdb.movies.csv')
t_m
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
t_m.drop(columns=['Unnamed: 0', 'original_language', 'original_title'], inplace=True)

# %%
t_m
# Out:
#                  genre_ids      id  popularity release_date  \
# 0          [12, 14, 10751]   12444      33.533   2010-11-19
# 1      [14, 12, 16, 10751]   10191      28.734   2010-03-26
# 2            [12, 28, 878]   10138      28.515   2010-05-07
# 3          [16, 35, 10751]     862      28.005   1995-11-22
# 4            [28, 878, 12]   27205      27.920   2010-07-16
# ...                    ...     ...         ...          ...
# 26512             [27, 18]  488143       0.600   2018-10-13
# 26513             [18, 53]  485975       0.600   2018-05-01
# 26514         [14, 28, 12]  381231       0.600   2018-10-01
# 26515      [10751, 12, 28]  366854       0.600   2018-06-22
# 26516             [53, 27]  309885       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 7 columns]

# %%
t_m.drop(columns=['genre_ids', 'id', 'vote_average', 'vote_count'], inplace=True)

# %%
t_m = t_m.drop('popularity', 1)
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/887611825.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   t_m = t_m.drop('popularity', 1)

# %%
df_merged2 = df_merged.merge(t_m, on = 'title', how = 'inner')

# %%
df_merged2
# Out:
#                          title  studio  year    genre 1    genre 2 genre 3  \
# 0                  Toy Story 3      BV  2010  Adventure  Animation  Comedy
# 1                  Toy Story 3      BV  2010  Adventure  Animation  Comedy
# 2                  Toy Story 3      BV  2010  Adventure  Animation  Comedy
# 3                  Toy Story 3      BV  2010  Adventure  Animation  Comedy
# 4                  Toy Story 3      BV  2010  Adventure  Animation  Comedy
# ...                        ...     ...   ...        ...        ...     ...
# 15780  Paul, Apostle of Christ  Affirm  2018  Adventure  Biography   Drama
# 15781  Paul, Apostle of Christ  Affirm  2018  Adventure  Biography   Drama
# 15782  Paul, Apostle of Christ  Affirm  2018  Adventure  Biography   Drama
# 15783  Paul, Apostle of Christ  Affirm  2018  Adventure  Biography   Drama
# 15784  Paul, Apostle of Christ  Affirm  2018  Adventure  Biography   Drama
#
#        worldwide_gross              job        primary_name release_date
# 0               1067.0         composer        Randy Newman   2010-06-17
# 1               1067.0            actor           Tom Hanks   2010-06-17
# 2               1067.0            actor           Tim Allen   2010-06-17
# 3               1067.0            actor         Joan Cusack   2010-06-17
# 4               1067.0            actor          Ned Beatty   2010-06-17
# ...                ...              ...                 ...          ...
# 15780             23.1         director        Andrew Hyatt   2018-03-28
# 15781             23.1           writer      Terence Berden   2018-03-28
# 15782             23.1         producer         David Zelon   2018-03-28
# 15783             23.1         composer  Jan A.P. Kaczmarek   2018-03-28
# 15784             23.1  cinematographer     Gerardo Madrazo   2018-03-28
#
# [15785 rows x 10 columns]

# %%
df_merged2.drop(columns = ['studio', 'year'], inplace = True)

# %%
df_merged2
# Out:
#                          title    genre 1    genre 2 genre 3  worldwide_gross  \
# 0                  Toy Story 3  Adventure  Animation  Comedy           1067.0
# 1                  Toy Story 3  Adventure  Animation  Comedy           1067.0
# 2                  Toy Story 3  Adventure  Animation  Comedy           1067.0
# 3                  Toy Story 3  Adventure  Animation  Comedy           1067.0
# 4                  Toy Story 3  Adventure  Animation  Comedy           1067.0
# ...                        ...        ...        ...     ...              ...
# 15780  Paul, Apostle of Christ  Adventure  Biography   Drama             23.1
# 15781  Paul, Apostle of Christ  Adventure  Biography   Drama             23.1
# 15782  Paul, Apostle of Christ  Adventure  Biography   Drama             23.1
# 15783  Paul, Apostle of Christ  Adventure  Biography   Drama             23.1
# 15784  Paul, Apostle of Christ  Adventure  Biography   Drama             23.1
#
#                    job        primary_name release_date
# 0             composer        Randy Newman   2010-06-17
# 1                actor           Tom Hanks   2010-06-17
# 2                actor           Tim Allen   2010-06-17
# 3                actor         Joan Cusack   2010-06-17
# 4                actor          Ned Beatty   2010-06-17
# ...                ...                 ...          ...
# 15780         director        Andrew Hyatt   2018-03-28
# 15781           writer      Terence Berden   2018-03-28
# 15782         producer         David Zelon   2018-03-28
# 15783         composer  Jan A.P. Kaczmarek   2018-03-28
# 15784  cinematographer     Gerardo Madrazo   2018-03-28
#
# [15785 rows x 8 columns]

# %%
pd.to_datetime(df_merged2['release_date'])
df_merged2['month'] = pd.DatetimeIndex(df_merged2['release_date']).month

# %%
df_merged2
# Out:
#                          title    genre 1    genre 2 genre 3  worldwide_gross  \
# 0                  Toy Story 3  Adventure  Animation  Comedy           1067.0
# 1                  Toy Story 3  Adventure  Animation  Comedy           1067.0
# 2                  Toy Story 3  Adventure  Animation  Comedy           1067.0
# 3                  Toy Story 3  Adventure  Animation  Comedy           1067.0
# 4                  Toy Story 3  Adventure  Animation  Comedy           1067.0
# ...                        ...        ...        ...     ...              ...
# 15780  Paul, Apostle of Christ  Adventure  Biography   Drama             23.1
# 15781  Paul, Apostle of Christ  Adventure  Biography   Drama             23.1
# 15782  Paul, Apostle of Christ  Adventure  Biography   Drama             23.1
# 15783  Paul, Apostle of Christ  Adventure  Biography   Drama             23.1
# 15784  Paul, Apostle of Christ  Adventure  Biography   Drama             23.1
#
#                    job        primary_name release_date  month
# 0             composer        Randy Newman   2010-06-17      6
# 1                actor           Tom Hanks   2010-06-17      6
# 2                actor           Tim Allen   2010-06-17      6
# 3                actor         Joan Cusack   2010-06-17      6
# 4                actor          Ned Beatty   2010-06-17      6
# ...                ...                 ...          ...    ...
# 15780         director        Andrew Hyatt   2018-03-28      3
# 15781           writer      Terence Berden   2018-03-28      3
# 15782         producer         David Zelon   2018-03-28      3
# 15783         composer  Jan A.P. Kaczmarek   2018-03-28      3
# 15784  cinematographer     Gerardo Madrazo   2018-03-28      3
#
# [15785 rows x 9 columns]

# %%
profit_month = df_merged2.groupby(['month']).worldwide_gross.mean()

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(15,6))
# Set x and y data
x = profit_month.index
y = profit_month.values 
# Create bar chart
ax.bar(x, y) 
# Set title and labels
ax.set_title('Worldwide Profit over Month')
ax.set_xlabel('Month')
ax.set_ylabel('Worldwide Profit (M)')
# Save figure
#plt.savefig('Worldwide Profit over Month.png')
# Out:
# Text(0, 0.5, 'Worldwide Profit (M)')

# %%
m_b = pd.read_csv('Data/tn.movie_budgets.csv')
m_b
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
m_b.info()
m_b.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
m_b = m_b.drop(columns=['release_date', 'id', 'domestic_gross'], axis = 1)
m_b
# Out:
#                                             movie production_budget  \
# 0                                          Avatar      $425,000,000
# 1     Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 2                                    Dark Phoenix      $350,000,000
# 3                         Avengers: Age of Ultron      $330,600,000
# 4               Star Wars Ep. VIII: The Last Jedi      $317,000,000
# ...                                           ...               ...
# 5777                                       Red 11            $7,000
# 5778                                    Following            $6,000
# 5779                Return to the Land of Wonders            $5,000
# 5780                         A Plague So Pleasant            $1,400
# 5781                            My Date With Drew            $1,100
#
#      worldwide_gross
# 0     $2,776,345,279
# 1     $1,045,663,875
# 2       $149,762,350
# 3     $1,403,013,963
# 4     $1,316,721,747
# ...              ...
# 5777              $0
# 5778        $240,495
# 5779          $1,338
# 5780              $0
# 5781        $181,041
#
# [5782 rows x 3 columns]

# %%
m_b.rename({'movie' : 'title'}, axis = 1, inplace=True)
m_b
# Out:
#                                             title production_budget  \
# 0                                          Avatar      $425,000,000
# 1     Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 2                                    Dark Phoenix      $350,000,000
# 3                         Avengers: Age of Ultron      $330,600,000
# 4               Star Wars Ep. VIII: The Last Jedi      $317,000,000
# ...                                           ...               ...
# 5777                                       Red 11            $7,000
# 5778                                    Following            $6,000
# 5779                Return to the Land of Wonders            $5,000
# 5780                         A Plague So Pleasant            $1,400
# 5781                            My Date With Drew            $1,100
#
#      worldwide_gross
# 0     $2,776,345,279
# 1     $1,045,663,875
# 2       $149,762,350
# 3     $1,403,013,963
# 4     $1,316,721,747
# ...              ...
# 5777              $0
# 5778        $240,495
# 5779          $1,338
# 5780              $0
# 5781        $181,041
#
# [5782 rows x 3 columns]

# %%
mb2 = m_b
mb2
# Out:
#                                             title production_budget  \
# 0                                          Avatar      $425,000,000
# 1     Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 2                                    Dark Phoenix      $350,000,000
# 3                         Avengers: Age of Ultron      $330,600,000
# 4               Star Wars Ep. VIII: The Last Jedi      $317,000,000
# ...                                           ...               ...
# 5777                                       Red 11            $7,000
# 5778                                    Following            $6,000
# 5779                Return to the Land of Wonders            $5,000
# 5780                         A Plague So Pleasant            $1,400
# 5781                            My Date With Drew            $1,100
#
#      worldwide_gross
# 0     $2,776,345,279
# 1     $1,045,663,875
# 2       $149,762,350
# 3     $1,403,013,963
# 4     $1,316,721,747
# ...              ...
# 5777              $0
# 5778        $240,495
# 5779          $1,338
# 5780              $0
# 5781        $181,041
#
# [5782 rows x 3 columns]

# %%
mb2[mb2.columns[1:]] = mb2[mb2.columns[1:]].replace('[\$,]', '', regex=True).astype(float)
m_b
# Out:
#                                             title  production_budget  \
# 0                                          Avatar        425000000.0
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                                    Dark Phoenix        350000000.0
# 3                         Avengers: Age of Ultron        330600000.0
# 4               Star Wars Ep. VIII: The Last Jedi        317000000.0
# ...                                           ...                ...
# 5777                                       Red 11             7000.0
# 5778                                    Following             6000.0
# 5779                Return to the Land of Wonders             5000.0
# 5780                         A Plague So Pleasant             1400.0
# 5781                            My Date With Drew             1100.0
#
#       worldwide_gross
# 0        2.776345e+09
# 1        1.045664e+09
# 2        1.497624e+08
# 3        1.403014e+09
# 4        1.316722e+09
# ...               ...
# 5777     0.000000e+00
# 5778     2.404950e+05
# 5779     1.338000e+03
# 5780     0.000000e+00
# 5781     1.810410e+05
#
# [5782 rows x 3 columns]

# %%
m_b['profit'] = m_b['worldwide_gross'] - m_b['production_budget']

# %%
m_b['ROI'] = m_b['profit']*100/m_b['production_budget']
m_b
# Out:
#                                             title  production_budget  \
# 0                                          Avatar        425000000.0
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                                    Dark Phoenix        350000000.0
# 3                         Avengers: Age of Ultron        330600000.0
# 4               Star Wars Ep. VIII: The Last Jedi        317000000.0
# ...                                           ...                ...
# 5777                                       Red 11             7000.0
# 5778                                    Following             6000.0
# 5779                Return to the Land of Wonders             5000.0
# 5780                         A Plague So Pleasant             1400.0
# 5781                            My Date With Drew             1100.0
#
#       worldwide_gross        profit           ROI
# 0        2.776345e+09  2.351345e+09    553.257713
# 1        1.045664e+09  6.350639e+08    154.667286
# 2        1.497624e+08 -2.002376e+08    -57.210757
# 3        1.403014e+09  1.072414e+09    324.384139
# 4        1.316722e+09  9.997217e+08    315.369636
# ...               ...           ...           ...
# 5777     0.000000e+00 -7.000000e+03   -100.000000
# 5778     2.404950e+05  2.344950e+05   3908.250000
# 5779     1.338000e+03 -3.662000e+03    -73.240000
# 5780     0.000000e+00 -1.400000e+03   -100.000000
# 5781     1.810410e+05  1.799410e+05  16358.272727
#
# [5782 rows x 5 columns]

# %%
df_merged3 = df_merged2.merge(m_b, on = 'title', how = 'inner')
df_merged3
# Out:
#                          title    genre 1    genre 2 genre 3  \
# 0                  Toy Story 3  Adventure  Animation  Comedy
# 1                  Toy Story 3  Adventure  Animation  Comedy
# 2                  Toy Story 3  Adventure  Animation  Comedy
# 3                  Toy Story 3  Adventure  Animation  Comedy
# 4                  Toy Story 3  Adventure  Animation  Comedy
# ...                        ...        ...        ...     ...
# 12444  Paul, Apostle of Christ  Adventure  Biography   Drama
# 12445  Paul, Apostle of Christ  Adventure  Biography   Drama
# 12446  Paul, Apostle of Christ  Adventure  Biography   Drama
# 12447  Paul, Apostle of Christ  Adventure  Biography   Drama
# 12448  Paul, Apostle of Christ  Adventure  Biography   Drama
#
#        worldwide_gross_x              job        primary_name release_date  \
# 0                 1067.0         composer        Randy Newman   2010-06-17
# 1                 1067.0            actor           Tom Hanks   2010-06-17
# 2                 1067.0            actor           Tim Allen   2010-06-17
# 3                 1067.0            actor         Joan Cusack   2010-06-17
# 4                 1067.0            actor          Ned Beatty   2010-06-17
# ...                  ...              ...                 ...          ...
# 12444               23.1         director        Andrew Hyatt   2018-03-28
# 12445               23.1           writer      Terence Berden   2018-03-28
# 12446               23.1         producer         David Zelon   2018-03-28
# 12447               23.1         composer  Jan A.P. Kaczmarek   2018-03-28
# 12448               23.1  cinematographer     Gerardo Madrazo   2018-03-28
#
#        month  production_budget  worldwide_gross_y       profit         ROI
# 0          6        200000000.0       1.068880e+09  868879522.0  434.439761
# 1          6        200000000.0       1.068880e+09  868879522.0  434.439761
# 2          6        200000000.0       1.068880e+09  868879522.0  434.439761
# 3          6        200000000.0       1.068880e+09  868879522.0  434.439761
# 4          6        200000000.0       1.068880e+09  868879522.0  434.439761
# ...      ...                ...                ...          ...         ...
# 12444      3          5000000.0       2.552950e+07   20529498.0  410.589960
# 12445      3          5000000.0       2.552950e+07   20529498.0  410.589960
# 12446      3          5000000.0       2.552950e+07   20529498.0  410.589960
# 12447      3          5000000.0       2.552950e+07   20529498.0  410.589960
# 12448      3          5000000.0       2.552950e+07   20529498.0  410.589960
#
# [12449 rows x 13 columns]

# %% [markdown]
# Questionable result????

# %%
df_director.sort_values(['worldwide_gross'],ascending=False)
# Out:
#                                 title  studio  year    genre 1    genre 2  \
# 7989          Avengers: Age of Ultron      BV  2015     Action  Adventure
# 9607                    Black Panther      BV  2018     Action  Adventure
# 11982  Jurassic World: Fallen Kingdom    Uni.  2018     Action  Adventure
# 7371                           Frozen      BV  2013  Adventure  Animation
# 8879                           Frozen      BV  2013  Adventure      Drama
# ...                               ...     ...   ...        ...        ...
# 8859                        Attenberg  Strand  2012      Drama       None
# 4513                  As Good as Dead   First  2010      Crime   Thriller
# 4530                           Inhale     IFC  2010      Drama   Thriller
# 8869                  Cirkus Columbia  Strand  2012     Comedy      Drama
# 7209                           Aurora    CGld  2011    Romance     Sci-Fi
#
#         genre 3  worldwide_gross       job            primary_name
# 7989     Sci-Fi        1405.4000  director             Joss Whedon
# 9607     Sci-Fi        1347.0000  director            Ryan Coogler
# 11982    Sci-Fi        1309.5000  director             J.A. Bayona
# 7371     Comedy        1276.4000  director            Jennifer Lee
# 8879      Sport        1276.4000  director              Adam Green
# ...         ...              ...       ...                     ...
# 8859       None           0.0699  director  Athina Rachel Tsangari
# 4513       None           0.0556  director         Jonathan Mossek
# 4530       None           0.0551  director       Baltasar Kormákur
# 8869    Romance           0.0130  director           Danis Tanovic
# 7209   Thriller           0.0108  director        Kristina Buozyte
#
# [1501 rows x 9 columns]

# %% [markdown]
# Importing budget data

# %%
m_b = pd.read_csv('Data/tn.movie_budgets.csv')
m_b
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
m_b = m_b.drop(columns=['release_date', 'id', 'domestic_gross'], axis = 1)

# %%
m_b.rename({'movie' : 'title'}, axis = 1, inplace=True)

# %%
m_b['production_budget'] = m_b['production_budget'].str.replace('$', '')
m_b['production_budget'] = m_b['production_budget'].str.replace(',', '')
m_b['worldwide_gross'] = m_b['worldwide_gross'].str.replace('$', '')
m_b['worldwide_gross'] = m_b['worldwide_gross'].str.replace(',', '')
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/3552646599.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   m_b['production_budget'] = m_b['production_budget'].str.replace('$', '')
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_61508/3552646599.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   m_b['worldwide_gross'] = m_b['worldwide_gross'].str.replace('$', '')

# %%
m_b['profit'] = m_b['worldwide_gross'].astype('int64') - m_b['production_budget'].astype('int64')

# %%
m_b = m_b.sort_values(by=['profit'], ascending=False)
m_b
# Out:
#                                     title production_budget worldwide_gross  \
# 0                                  Avatar         425000000      2776345279
# 42                                Titanic         200000000      2208208395
# 6                  Avengers: Infinity War         300000000      2048134200
# 5    Star Wars Ep. VII: The Force Awakens         306000000      2053311220
# 33                         Jurassic World         215000000      1648854864
# ..                                    ...               ...             ...
# 352                        Town & Country         105000000        10364769
# 341           Men in Black: International         110000000         3100000
# 193                       Mars Needs Moms         150000000        39549758
# 194                              Moonfall         150000000               0
# 2                            Dark Phoenix         350000000       149762350
#
#          profit
# 0    2351345279
# 42   2008208395
# 6    1748134200
# 5    1747311220
# 33   1433854864
# ..          ...
# 352   -94635231
# 341  -106900000
# 193  -110450242
# 194  -150000000
# 2    -200237650
#
# [5782 rows x 4 columns]

# %% [markdown]
# Finding directors total gross

# %%
df_director.sort_values(by='worldwide_gross', ascending=False)
# Out:
#                                 title  studio  year    genre 1    genre 2  \
# 7989          Avengers: Age of Ultron      BV  2015     Action  Adventure
# 9607                    Black Panther      BV  2018     Action  Adventure
# 11982  Jurassic World: Fallen Kingdom    Uni.  2018     Action  Adventure
# 7371                           Frozen      BV  2013  Adventure  Animation
# 8879                           Frozen      BV  2013  Adventure      Drama
# ...                               ...     ...   ...        ...        ...
# 8859                        Attenberg  Strand  2012      Drama       None
# 4513                  As Good as Dead   First  2010      Crime   Thriller
# 4530                           Inhale     IFC  2010      Drama   Thriller
# 8869                  Cirkus Columbia  Strand  2012     Comedy      Drama
# 7209                           Aurora    CGld  2011    Romance     Sci-Fi
#
#         genre 3  worldwide_gross       job            primary_name
# 7989     Sci-Fi        1405.4000  director             Joss Whedon
# 9607     Sci-Fi        1347.0000  director            Ryan Coogler
# 11982    Sci-Fi        1309.5000  director             J.A. Bayona
# 7371     Comedy        1276.4000  director            Jennifer Lee
# 8879      Sport        1276.4000  director              Adam Green
# ...         ...              ...       ...                     ...
# 8859       None           0.0699  director  Athina Rachel Tsangari
# 4513       None           0.0556  director         Jonathan Mossek
# 4530       None           0.0551  director       Baltasar Kormákur
# 8869    Romance           0.0130  director           Danis Tanovic
# 7209   Thriller           0.0108  director        Kristina Buozyte
#
# [1501 rows x 9 columns]

# %%
#df_director['total_gross'] = df_director['primary_name'].groupby(df_director['worldwide_gross']).sum()

df_director['primary_name'].duplicated().value_counts()
# Out:
# False    1021
# True      480
# Name: primary_name, dtype: int64

# %%
#df_director['total_gross'] = groupyby('primary_name')['worldwide_gross'].sum()

# %%
df_director.head(10)
# Out:
#                     title studio  year    genre 1    genre 2  genre 3  \
# 20            Toy Story 3     BV  2010  Adventure  Animation   Comedy
# 21                   Coco     BV  2017  Adventure  Animation   Comedy
# 23                 Cars 2     BV  2011  Adventure  Animation   Comedy
# 26            John Carter     BV  2012     Action  Adventure   Sci-Fi
# 27           Finding Dory     BV  2016  Adventure  Animation   Comedy
# 60              Inception     WB  2010     Action  Adventure   Sci-Fi
# 61  The Dark Knight Rises     WB  2012     Action   Thriller     None
# 63           Interstellar   Par.  2014  Adventure      Drama   Sci-Fi
# 64                Dunkirk     WB  2017     Action      Drama  History
# 80          Transcendence     WB  2014     Action      Drama   Sci-Fi
#
#     worldwide_gross       job       primary_name      total_gross  Total_Gross
# 20           1067.0  director        Lee Unkrich              NaN       1874.1
# 21            807.1  director        Lee Unkrich              NaN       1874.1
# 23            562.2  director      John Lasseter              NaN        562.2
# 26            284.2  director     Andrew Stanton              NaN       1312.8
# 27           1028.6  director     Andrew Stanton              NaN       1312.8
# 60            828.3  director  Christopher Nolan    Roger Michell       3115.8
# 61           1084.9  director  Christopher Nolan  Olivier Megaton       3115.8
# 63            677.4  director  Christopher Nolan              NaN       3115.8
# 64            525.2  director  Christopher Nolan              NaN       3115.8
# 80            103.0  director      Wally Pfister              NaN        103.0

# %%
show = df_director.loc[df_director['worldwide_gross']]
show
# Out:
# Empty DataFrame
# Columns: [title, studio, year, genre 1, genre 2, genre 3, worldwide_gross, job, primary_name, total_gross, Total_Gross]
# Index: []
