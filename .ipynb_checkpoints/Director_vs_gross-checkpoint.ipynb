# %%
import pandas as pd
import numpy as np

# %%
m_b = pd.read_csv('Data/tn.movie_budgets.csv')
m_b
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
m_b = m_b.drop(columns=['release_date', 'id', 'domestic_gross'], axis = 1)

# %%
m_b.rename({'movie' : 'title'}, axis = 1, inplace=True)

# %%
m_b['production_budget'] = m_b['production_budget'].str.replace('$', '')
m_b['production_budget'] = m_b['production_budget'].str.replace(',', '')
m_b['worldwide_gross'] = m_b['worldwide_gross'].str.replace('$', '')
m_b['worldwide_gross'] = m_b['worldwide_gross'].str.replace(',', '')
m_b.drop(columns='domestic_gross', inplace=True)
# Out:
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_68629/2681288985.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   m_b['production_budget'] = m_b['production_budget'].str.replace('$', '')
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_68629/2681288985.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   m_b['worldwide_gross'] = m_b['worldwide_gross'].str.replace('$', '')

# %%
m_b
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget worldwide_gross
# 0            425000000      2776345279
# 1            410600000      1045663875
# ...

# %%
#m_b['profit'] = m_b['worldwide_gross'].astype('int64') - m_b['production_budget'].astype('int64')

# %%
m_b['year'] = pd.DatetimeIndex(m_b['release_date']).year
m_b['title'] = m_b['movie']
m_b.drop(columns='movie')
# Out:
#       id  release_date production_budget worldwide_gross  year  \
# 0      1  Dec 18, 2009         425000000      2776345279  2009
# 1      2  May 20, 2011         410600000      1045663875  2011
# 2      3   Jun 7, 2019         350000000       149762350  2019
# 3      4   May 1, 2015         330600000      1403013963  2015
# 4      5  Dec 15, 2017         317000000      1316721747  2017
# ...   ..           ...               ...             ...   ...
# 5777  78  Dec 31, 2018              7000               0  2018
# 5778  79   Apr 2, 1999              6000          240495  1999
# 5779  80  Jul 13, 2005              5000            1338  2005
# 5780  81  Sep 29, 2015              1400               0  2015
# 5781  82   Aug 5, 2005              1100          181041  2005
#
#                                             title
# 0                                          Avatar
# 1     Pirates of the Caribbean: On Stranger Tides
# 2                                    Dark Phoenix
# ...

# %% [markdown]
# Import data frame with movies directed by

# %%
dir_df = pd.read_csv('Data/IMDb_movies.csv')
dir_df.drop(columns=['imdb_title_id', 'original_title', 'date_published', 'duration', 'country', 'description', 'avg_vote', 'votes', 'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore', 'reviews_from_users', 'reviews_from_critics'], inplace=True)
# Out:
# /Users/stephen/opt/anaconda3/envs/new-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dir_df
# Out:
#                                 title  year                      genre  \
# 0                          Miss Jerry  1894                    Romance
# 1         The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2                      Den sorte drøm  1911                      Drama
# 3                           Cleopatra  1912             Drama, History
# 4                           L'Inferno  1911  Adventure, Drama, Fantasy
# ...                               ...   ...                        ...
# 85850                         Le lion  2020                     Comedy
# 85851  De Beentjes van Sint-Hildegard  2020              Comedy, Drama
# 85852       Padmavyuhathile Abhimanyu  2019                      Drama
# 85853               Sokagin Çocuklari  2019              Drama, Family
# 85854      La vida sense la Sara Amat  2019                      Drama
#
#             language                             director  \
# ...

# %%
merged_df = dir_df.merge(m_b, how='inner', on=['title', 'year'])
merged_df.groupby('director')['worldwide_gross'].sum()
# Out:
# director
# Abbas Alibhai Burmawalla, Mastan Alibhai Burmawalla                      14623082
# Adam Jay Epstein, Andrew Jacobson                                           81338
# Adam Rifkin                                                               5825314
# Adam Shankman                                                            61031932
# Adam Thomas Anderegg                                                       814666
#                                                                   ...
# Zack Snyder                                            18697625065594520989758389
# Zak Penn                                                                    56073
# Zal Batmanglij                                                            3027956
# Émile Gaudreault                                                         12399772
# Éric Besnard                                                             11738256
# Name: worldwide_gross, Length: 952, dtype: object

# %%
merged_df.sort_values(by='worldwide_gross', ascending=False)
# Out:
#                                   title  year                      genre  \
# 336                             Hellboy  2004    Action, Fantasy, Horror
# 607                                Duma  2005   Adventure, Drama, Family
# 73                               Brazil  1985              Drama, Sci-Fi
# 452                    The Time Machine  2002  Action, Adventure, Sci-Fi
# 569                            Paycheck  2003    Action, Mystery, Sci-Fi
# ...                                 ...   ...                        ...
# 847                   A Dog's Breakfast  2007      Comedy, Drama, Horror
# 519               George and the Dragon  2004  Action, Adventure, Comedy
# 1293                        The Helpers  2012                     Horror
# 980   No Man's Land: The Rise of Reeker  2008           Horror, Thriller
# 784       House at the End of the Drive  2014           Horror, Thriller
#
#               language            director  \
# 336   English, Russian  Guillermo del Toro
# ...

# %%
merged_df.loc[merged_df['title']=='Avatar']
# Out:
#       title  year                       genre          language  \
# 834  Avatar  2009  Action, Adventure, Fantasy  English, Spanish
#
#           director         writer     production_company  \
# 834  James Cameron  James Cameron  Twentieth Century Fox
#
#                                                 actors  id  release_date  \
# 834  Sam Worthington, Zoe Saldana, Sigourney Weaver...   1  Dec 18, 2009
#
#       movie production_budget worldwide_gross
# 834  Avatar         425000000      2776345279

# %%
merged_df.loc[merged_df['director']=='James Cameron']
# Out:
#          title  year                       genre  \
# 104  The Abyss  1989   Adventure, Drama, Mystery
# 141  True Lies  1994    Action, Comedy, Thriller
# 238    Titanic  1997              Drama, Romance
# 834     Avatar  2009  Action, Adventure, Fantasy
#
#                               language       director  \
# 104                            English  James Cameron
# 141    English, French, Arabic, German  James Cameron
# 238  English, Swedish, Italian, French  James Cameron
# 834                   English, Spanish  James Cameron
#
#                          writer     production_company  \
# 104               James Cameron  Twentieth Century Fox
# 141  Claude Zidi, Simon Michaël  Twentieth Century Fox
# 238               James Cameron  Twentieth Century Fox
# 834               James Cameron  Twentieth Century Fox
#
#                                                 actors  id  release_date  \
# 104  Ed Harris, Mary Elizabeth Mastrantonio, Michae...  23   Aug 9, 1989
# ...

# %%
#merged_df['worldwide_gross'].astype('int64')

# %%
merged_df.sort_values(by='worldwide_gross', ascending=False)
# Out:
#                                   title  year                      genre  \
# 336                             Hellboy  2004    Action, Fantasy, Horror
# 607                                Duma  2005   Adventure, Drama, Family
# 73                               Brazil  1985              Drama, Sci-Fi
# 452                    The Time Machine  2002  Action, Adventure, Sci-Fi
# 569                            Paycheck  2003    Action, Mystery, Sci-Fi
# ...                                 ...   ...                        ...
# 847                   A Dog's Breakfast  2007      Comedy, Drama, Horror
# 519               George and the Dragon  2004  Action, Adventure, Comedy
# 1293                        The Helpers  2012                     Horror
# 980   No Man's Land: The Rise of Reeker  2008           Horror, Thriller
# 784       House at the End of the Drive  2014           Horror, Thriller
#
#               language            director  \
# 336   English, Russian  Guillermo del Toro
# ...

# %%
merged_df['worldwide_gross'].max()
#merged_df['worldwide_gross'].sum()
# Out:
# '99823958'
