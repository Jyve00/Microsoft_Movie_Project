# %% [markdown]
# # Data Cleaning bom.movie

# %%
import pandas as pd
import numpy as np

# %%
# !ls

# %%
bom = pd.read_csv('bom.movie_gross.csv')

# %%
bom.info()

# %%
bom['foreign_gross'] = bom['foreign_gross'].replace(',','', regex = True)
#getting rid of commas so I can covert string to a float

# %%
bom['foreign_gross']= bom['foreign_gross'].astype(float)
#converting string to float

# %%
top_500_dom = bom.nlargest(500, ['domestic_gross'])

# %%
top_500_dom.isna().sum()
#looking to find if there are many null values in the top 500 movies
#null values aren't relevant in top 500 which means we can get rid of all rows that have nulls

# %%
bom = bom[bom['domestic_gross'].notna()]

# %%
bom = bom[bom['studio'].notna()]

# %%
bom = bom[bom['foreign_gross'].notna()]

#getting rid of missing values

# %%
bom
# Out:
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross  foreign_gross  year
# 0        415000000.0    652000000.0  2010
# ...

# %%
bom
# Out:
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross  foreign_gross  year
# 0        415000000.0    652000000.0  2010
# ...

# %% [markdown]
# ## Data cleaning name.basics

# %%
n_b = pd.read_csv('name.basics.csv')

# %%
n_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   nconst              606648 non-null  object
#  1   primary_name        606648 non-null  object
#  2   birth_year          82736 non-null   float64
#  3   death_year          6783 non-null    float64
#  4   primary_profession  555308 non-null  object
#  5   known_for_titles    576444 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 27.8+ MB

# %%
n_b = n_b.drop('birth_year', 1)
#deleted birth year because not relevant

# %%
n_b = n_b[n_b['death_year'].isna()]
#got rid of any people who are dead

# %%
n_b = n_b.drop('death_year', 1)
#got rid of death year because no longer relevant

# %%
n_b = n_b[n_b['known_for_titles'].notna()]
# got rid of na values in title id

# %%
n_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 569766 entries, 0 to 606647
# Data columns (total 4 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   nconst              569766 non-null  object
#  1   primary_name        569766 non-null  object
#  2   primary_profession  529154 non-null  object
#  3   known_for_titles    569766 non-null  object
# dtypes: object(4)
# memory usage: 21.7+ MB

# %%
n_b = n_b[n_b['primary_profession'].notna()]
#got rid of na values in primary profession

# %%
n_b
# Out:
#            nconst        primary_name  \
# 0       nm0061671   Mary Ellen Bauder
# 1       nm0061865        Joseph Bauer
# 2       nm0062070          Bruce Baum
# 3       nm0062195        Axel Baumann
# 4       nm0062798         Pete Baxter
# ...           ...                 ...
# 606639  nm9989840  Mariya Shekaturova
# 606640  nm9989854        Layla Louise
# 606644  nm9990690         Joo Yeon So
# 606645  nm9991320      Madeline Smith
# 606647  nm9993380      Pegasus Envoyé
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606639                                             actor
# ...

# %% [markdown]
# # Data cleaning title.akas

# %%
t_a = pd.read_csv('title.akas.csv')

# %%
t_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   title_id           331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   language           41715 non-null   object
#  5   types              168447 non-null  object
#  6   attributes         14925 non-null   object
#  7   is_original_title  331678 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.2+ MB

# %%
t_a = t_a.drop('language', 1)

#dropped language because too many na's

# %%
t_a = t_a.drop('types', 1)
#dropped types because too many na's, not relevant

# %%
t_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   title_id           331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   attributes         14925 non-null   object
#  5   is_original_title  331678 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 15.2+ MB

# %%
t_a = t_a.drop('attributes', 1)
#dropped attributes because too many na's

# %%
# t_a.set_index('title_id', inplace = True)
# setting the title id as index

# %%
t_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   title_id           331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   is_original_title  331678 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 12.7+ MB

# %%
is_original_title = t_a['is_original_title'] == 1

# %%
is_original_title = t_a[is_original_title]

# %%
t_a = is_original_title
#I only want original titles to get rid of repeats

# %%
t_a = t_a.drop('region', 1)

# %%
t_a = t_a.drop('ordering', 1)
#region and ordering are not relevant

# %%
t_a
# Out:
#           title_id                                              title  \
# 38       tt0369610                                     Jurassic World
# 80       tt0401729                                        John Carter
# 83      tt10010134  Versailles Rediscovered - The Sun King's Vanis...
# 86      tt10027708                      Miguelito - Canto a Borinquen
# 90      tt10050722                                  Thing I Don't Get
# ...            ...                                                ...
# 331690   tt9723084                         Anderswo. Allein in Afrika
# 331692   tt9726638                           Monkey King: The Volcano
# 331696   tt9755806                                          Big Shark
# 331698   tt9827784                                 Sayonara kuchibiru
# 331700   tt9880178                                        La atención
#
#         is_original_title
# 38                    1.0
# 80                    1.0
# 83                    1.0
# ...

# %% [markdown]
# #data cleaning title basics

# %%
# !ls
# Out:
# Derek's datacleaning and visualization.ipynb
# README.md
# bom.movie_gross.csv
# name.basics.csv
# rt.movie_info.tsv
# rt.reviews.tsv
# title.akas.csv
# title.basics.csv
# title.crew.csv
# title.principals.csv
# title.ratings.csv
# tmdb.movies.csv
# tn.movie_budgets.csv

# %% [markdown]
# # Data cleaning title basics

# %%
t_b = pd.read_csv('title.basics.csv')

# %%
t_b
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
t_b = t_b.drop('runtime_minutes', 1)
#don think runtime is relevant data

# %%
t_b = t_b[t_b['genres'].notna()]
#getting rid of na values in genres

# %%
t_b = t_b.drop('original_title', 1)
#getting rid of og title because not necessary

# %% [markdown]
# # data cleaning title crew

# %%
t_c = pd.read_csv('title.crew.csv')

# %%
t_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  140417 non-null  object
#  2   writers    110261 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
t_c = t_c[t_c['directors'].notna()]

# %%
t_c = t_c[t_c['writers'].notna()]
#got rid of na values

# %% [markdown]
# # data cleaning title principals

# %%
t_p = pd.read_csv('title.principals.csv')

# %%
t_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   tconst      1028186 non-null  object
#  1   ordering    1028186 non-null  int64
#  2   nconst      1028186 non-null  object
#  3   category    1028186 non-null  object
#  4   job         177684 non-null   object
#  5   characters  393360 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB

# %%
t_p = t_p.drop('characters',1)
# dropped characters not relevant

# %%
t_p = t_p.drop('ordering',1)

# %%
t_p = t_p.drop('job', 1)

# %%
t_p.rename({'category':'job'}, axis = 1, inplace = True)
#changed category to job because more accurate

# %% [markdown]
# # Data cleaning title rating

# %%
t_r = pd.read_csv('title.ratings.csv')

# %%
t_r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
t_r
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %% [markdown]
# # combining imbd

# %%
tb_join_tc = pd.merge(t_b,t_c, on = ['tconst'])
#merging tb and tc using tconst

# %%
tb_join_tc= tb_join_tc.drop('directors', 1)
#dropping directors because we already have nconst

# %%
tb_join_tc = tb_join_tc.drop('writers',1)
#dropping writers because we already have #nconst

# %%
tb_tc_tp_merge = pd.merge (tb_join_tc, t_p, on = ['tconst'])
#merging tp into the final dataframe

# %%
tb_tc_tp_merge
# Out:
#            tconst                   primary_title  start_year  \
# 0       tt0063540                       Sunghursh        2013
# 1       tt0063540                       Sunghursh        2013
# 2       tt0063540                       Sunghursh        2013
# 3       tt0063540                       Sunghursh        2013
# 4       tt0063540                       Sunghursh        2013
# ...           ...                             ...         ...
# 839872  tt9916754  Chico Albuquerque - Revelações        2013
# 839873  tt9916754  Chico Albuquerque - Revelações        2013
# 839874  tt9916754  Chico Albuquerque - Revelações        2013
# 839875  tt9916754  Chico Albuquerque - Revelações        2013
# 839876  tt9916754  Chico Albuquerque - Revelações        2013
#
#                     genres      nconst              job
# 0       Action,Crime,Drama   nm0006210         composer
# 1       Action,Crime,Drama   nm0474801            actor
# ...

# %%
n_b
# Out:
#            nconst        primary_name  \
# 0       nm0061671   Mary Ellen Bauder
# 1       nm0061865        Joseph Bauer
# 2       nm0062070          Bruce Baum
# 3       nm0062195        Axel Baumann
# 4       nm0062798         Pete Baxter
# ...           ...                 ...
# 606639  nm9989840  Mariya Shekaturova
# 606640  nm9989854        Layla Louise
# 606644  nm9990690         Joo Yeon So
# 606645  nm9991320      Madeline Smith
# 606647  nm9993380      Pegasus Envoyé
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606639                                             actor
# ...

# %%
n_b = n_b.drop('known_for_titles', 1)

#this column is no longer relevant, we have tconst column

# %%
n_b = n_b.drop('primary_profession', 1)

# %%
imbd_merge = pd.merge(tb_tc_tp_merge, n_b, on = ['nconst'])
#this is the final merge, putting nb into final dataframe

# %%
imbd_merge
# Out:
#            tconst                   primary_title  start_year  \
# 0       tt0063540                       Sunghursh        2013
# 1       tt0063540                       Sunghursh        2013
# 2       tt0063540                       Sunghursh        2013
# 3       tt0069204                 Sabse Bada Sukh        2018
# 4       tt0357717                       Haar Jeet        2018
# ...           ...                             ...         ...
# 783066  tt9916706                 Dankyavar Danka        2013
# 783067  tt9916706                 Dankyavar Danka        2013
# 783068  tt9916706                 Dankyavar Danka        2013
# 783069  tt9916754  Chico Albuquerque - Revelações        2013
# 783070  tt9916754  Chico Albuquerque - Revelações        2013
#
#                     genres      nconst              job         primary_name
# 0       Action,Crime,Drama   nm0474801            actor          Dilip Kumar
# ...

# %%
imbd_merge = imbd_merge.drop('known_for_titles', 1)
#dropped known for titles because not necessary
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-121-85f211a233d5> in <module>
# ----> 1 imbd_merge = imbd_merge.drop('known_for_titles', 1)
#       2 #dropped known for titles because not necessary
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
# ...

# %%
final_movie_list = list(set(imbd_merge['primary_title']) & set(bom['title']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'primary_title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-157-e7cf2424c853> in <module>
# ...

# %%
final_movie_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-122-7d233cd21508> in <module>
# ----> 1 final_movie_list
#
# NameError: name 'final_movie_list' is not defined

# %%
imbd_merge
# Out:
#            tconst                   primary_title  start_year  \
# 0       tt0063540                       Sunghursh        2013
# 1       tt0063540                       Sunghursh        2013
# 2       tt0063540                       Sunghursh        2013
# 3       tt0069204                 Sabse Bada Sukh        2018
# 4       tt0357717                       Haar Jeet        2018
# ...           ...                             ...         ...
# 783066  tt9916706                 Dankyavar Danka        2013
# 783067  tt9916706                 Dankyavar Danka        2013
# 783068  tt9916706                 Dankyavar Danka        2013
# 783069  tt9916754  Chico Albuquerque - Revelações        2013
# 783070  tt9916754  Chico Albuquerque - Revelações        2013
#
#                     genres      nconst              job         primary_name
# 0       Action,Crime,Drama   nm0474801            actor          Dilip Kumar
# ...

# %%
imbd_merge['primary_title'].isin(final_movie_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-124-74afd386704b> in <module>
# ----> 1 imbd_merge['primary_title'].isin(final_movie_list)
#
# NameError: name 'final_movie_list' is not defined

# %%
imbd_merge = imbd_merge[imbd_merge['primary_title'].isin(final_movie_list)]
#this makes imbd_merg oly have movies that is in the list i created earlier
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-5450de2dc6d4> in <module>
# ----> 1 imbd_merge = imbd_merge[imbd_merge['primary_title'].isin(final_movie_list)]
#       2 #this makes imbd_merg oly have movies that is in the list i created earlier
#
# NameError: name 'final_movie_list' is not defined

# %%
imbd_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783071 entries, 0 to 783070
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         783071 non-null  object
#  1   primary_title  783071 non-null  object
#  2   start_year     783071 non-null  int64
#  3   genres         783071 non-null  object
#  4   nconst         783071 non-null  object
#  5   job            783071 non-null  object
#  6   primary_name   783071 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 47.8+ MB

# %%
imbd_merge = imbd_merge.rename({'primary_title':'title'}, axis = 1)

# %%
imbd_merge
# Out:
#            tconst                           title  start_year  \
# 0       tt0063540                       Sunghursh        2013
# 1       tt0063540                       Sunghursh        2013
# 2       tt0063540                       Sunghursh        2013
# 3       tt0069204                 Sabse Bada Sukh        2018
# 4       tt0357717                       Haar Jeet        2018
# ...           ...                             ...         ...
# 783066  tt9916706                 Dankyavar Danka        2013
# 783067  tt9916706                 Dankyavar Danka        2013
# 783068  tt9916706                 Dankyavar Danka        2013
# 783069  tt9916754  Chico Albuquerque - Revelações        2013
# 783070  tt9916754  Chico Albuquerque - Revelações        2013
#
#                     genres      nconst              job         primary_name
# 0       Action,Crime,Drama   nm0474801            actor          Dilip Kumar
# ...

# %%
final_merge = pd.merge(imbd_merge, bom, on = 'title')
#final dataset with everything we need

# %%
final_merge
# Out:
#           tconst                                        title  start_year  \
# 0      tt0938283                           The Last Airbender        2010
# 1      tt0938283                           The Last Airbender        2010
# 2      tt0938283                           The Last Airbender        2010
# 3      tt0938283                           The Last Airbender        2010
# 4      tt0938283                           The Last Airbender        2010
# ...          ...                                          ...         ...
# 17357  tt5544384  Sword Art Online: The Movie - Ordinal Scale        2017
# 17358  tt5544384  Sword Art Online: The Movie - Ordinal Scale        2017
# 17359  tt8851262                                 Spring Fever        2019
# 17360  tt8851262                                 Spring Fever        2019
# 17361  tt8851262                                 Spring Fever        2019
#
#                            genres     nconst       job           primary_name  \
# ...

# %%
final_merge = final_merge.drop('start_year',1)

# %%
final_merge['worldwide_gross'] = final_merge['domestic_gross'] + final_merge['foreign_gross']
#creating worldwide gross by addinf domestic and foreign

# %%
tn = pd.read_csv('tn.movie_budgets.csv')

# %%
tn
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
tn['production_budget'] = tn['production_budget'].replace(',','', regex = True)
tn['production_budget'] = tn['production_budget'].str.replace('$','', regex = True)
tn['domestic_gross'] = tn['domestic_gross'].replace(',','', regex = True)
tn['domestic_gross'] = tn['domestic_gross'].str.replace('$','', regex = True)
tn['worldwide_gross'] = tn['worldwide_gross'].replace(',','', regex = True)
tn['worldwide_gross'] = tn['worldwide_gross'].str.replace('$','', regex = True)

#replacing commas and dollarsigns to turn str to int

# %%
tn['production_budget']= tn['production_budget'].astype(float)
tn['domestic_gross']= tn['domestic_gross'].astype(float)
tn['worldwide_gross']= tn['worldwide_gross'].astype(float)

# %%
tn['profit']= tn['worldwide_gross']-tn['production_budget']
tn['ROI']= (tn['profit']/tn['production_budget'])*100
#creating new columns for profit and roi

# %%
tn = tn.drop('release_date', 1)
tn = tn.drop('id', 1)
#dropping release date and id

# %%
tn = tn.rename({'movie':'title'}, axis = 1)

# %%
final_merge = pd.merge(final_merge, tn, on ='title')

# %%
final_merge
# Out:
#           tconst                title                   genres     nconst  \
# 0      tt0938283   The Last Airbender  Action,Adventure,Family  nm0550881
# 1      tt0938283   The Last Airbender  Action,Adventure,Family  nm2353862
# 2      tt0938283   The Last Airbender  Action,Adventure,Family  nm0119322
# 3      tt0938283   The Last Airbender  Action,Adventure,Family  nm3226241
# 4      tt0938283   The Last Airbender  Action,Adventure,Family  nm2443758
# ...          ...                  ...                      ...        ...
# 11661  tt2321549         The Babadook             Drama,Horror  nm0568399
# 11662  tt2321549         The Babadook             Drama,Horror  nm0448768
# 11663  tt2321549         The Babadook             Drama,Horror  nm0373829
# 11664  tt2321549         The Babadook             Drama,Horror  nm1202788
# 11665  tt4074762  Life During Wartime      Documentary,History  nm0392850
#
#             job       primary_name studio  domestic_gross_x  foreign_gross  \
# ...

# %% [markdown]
# # data visualization

# %%
directors = final_merge[final_merge['job'] == 'director']

# %%
unique_titles_df = directors.drop_duplicates(subset= ['title'])

# %%
final_merge = final_merge.drop('domestic_gross_x', 1)
final_merge = final_merge.drop('worldwide_gross_x', 1)

# %%
directors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1323 entries, 6 to 11665
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             1323 non-null   object
#  1   title              1323 non-null   object
#  2   genres             1323 non-null   object
#  3   nconst             1323 non-null   object
#  4   job                1323 non-null   object
#  5   primary_name       1323 non-null   object
#  6   studio             1323 non-null   object
#  7   domestic_gross_x   1323 non-null   float64
#  8   foreign_gross      1323 non-null   float64
#  9   year               1323 non-null   int64
#  10  worldwide_gross_x  1323 non-null   float64
#  11  production_budget  1323 non-null   float64
#  12  domestic_gross_y   1323 non-null   float64
#  13  worldwide_gross_y  1323 non-null   float64
#  14  profit             1323 non-null   float64
# ...

# %%
profit_directors = directors.groupby('primary_name')['profit'].sum().sort_values(ascending=False)

# %%
top_50_directors = profit_directors.nlargest(50)

# %%
top_50_directors_profit = top_50_directors.values.sum()

#created a top_50 directors based on profit

# %%
total_profit = unique_titles_df['profit'].sum()

# %%
top_50_directors_profit_perc = top_50_directors_profit/total_profit

#dividing the total profit from the top 50 directors by the total profit in the dataset to see how much can be attributed to top 50 directors

# %%
top_50_directors_profit_perc
# Out:
# 0.5480996249334049

# %%
unique_titles_df[unique_titles_df['title'].str.contains('Avengers')]
# Out:
#          tconst                    title                   genres     nconst  \
# 5237  tt2395427  Avengers: Age of Ultron  Action,Adventure,Sci-Fi  nm0923736
# 5253  tt4154756   Avengers: Infinity War  Action,Adventure,Sci-Fi  nm0751577
#
#            job   primary_name studio  domestic_gross_x  foreign_gross  year  \
# 5237  director    Joss Whedon     BV       459000000.0    946400000.0  2015
# 5253  director  Anthony Russo     BV       678800000.0         1369.5  2018
#
#       worldwide_gross_x  production_budget  domestic_gross_y  \
# 5237       1.405400e+09        330600000.0       459005868.0
# 5253       6.788014e+08        300000000.0       678815482.0
#
#       worldwide_gross_y        profit         ROI
# 5237       1.403014e+09  1.072414e+09  324.384139
# 5253       2.048134e+09  1.748134e+09  582.711400

# %%
rest_profit = 1 - top_50_directors_profit_perc

# %%
import matplotlib.pyplot as plt

# %%
my_data = [rest_profit, top_50_directors_profit_perc]
my_labels = 'Everyone else', 'Top 50 profitable directors'
my_colors = ['lightblue','silver']
my_explode = (0, 0.1)
plt.pie(my_data,labels = my_labels,autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.title('Total Profit')
plt.axis('equal')
plt.show()

#graphing pie plot to show signifigance
